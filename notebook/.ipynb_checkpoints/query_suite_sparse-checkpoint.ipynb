# %%
import ssgetpy
import json
import os

def fetch_and_store_results(filename="ss_matrix_metadata.json"):
    # Clear the metadata file if it exists
    if os.path.exists(filename):
        os.remove(filename)
        print(f"Existing metadata file '{filename}' cleared.")
        
    print("Fetching all results...")
    results = ssgetpy.search(limit=3000)  #There are 2893 total matrices in the Suite Sparse Matrix Collection
    print(f"Total matrices found: {len(results)}")

    matrix_metadata = []
    for i, result in enumerate(results):
        print(f"Processing matrix {i + 1}/{len(results)}: {result.name}")
        total_elements = result.rows * result.cols
        sparsity = 1 - (result.nnz / total_elements)

        matrix_metadata.append({
            "id": result.id,
            "name": result.name,
            "group": result.group,
            "rows": result.rows,
            "cols": result.cols,
            "nnz": result.nnz,
            "sparsity": sparsity,
            "kind": result.kind,
            "is2d3d": result.is2d3d,
            "isSPD": result.isspd
        })

    
    with open(filename, "w") as f:
        json.dump(matrix_metadata, f, indent=4)

    print(f"Matrix metadata saved to {filename}")

if __name__ == "__main__":

    metadata_file = "ss_matrix_metadata.json"
    fetch_and_store_results(metadata_file)
# Out:
# Fetching all results...
# Total matrices found: 2904
# Processing matrix 1/2904: 1138_bus
# Processing matrix 2/2904: 494_bus
# Processing matrix 3/2904: 662_bus
# Processing matrix 4/2904: 685_bus
# Processing matrix 5/2904: abb313
# Processing matrix 6/2904: arc130
# Processing matrix 7/2904: ash219
# Processing matrix 8/2904: ash292
# Processing matrix 9/2904: ash331
# Processing matrix 10/2904: ash608
# Processing matrix 11/2904: ash85
# Processing matrix 12/2904: ash958
# Processing matrix 13/2904: bcspwr01
# Processing matrix 14/2904: bcspwr02
# Processing matrix 15/2904: bcspwr03
# Processing matrix 16/2904: bcspwr04
# Processing matrix 17/2904: bcspwr05
# Processing matrix 18/2904: bcspwr06
# Processing matrix 19/2904: bcspwr07
# Processing matrix 20/2904: bcspwr08
# Processing matrix 21/2904: bcspwr09
# Processing matrix 22/2904: bcspwr10
# Processing matrix 23/2904: bcsstk01
# Processing matrix 24/2904: bcsstk02
# Processing matrix 25/2904: bcsstk03
# Processing matrix 26/2904: bcsstk04
# Processing matrix 27/2904: bcsstk05
# Processing matrix 28/2904: bcsstk06
# Processing matrix 29/2904: bcsstk07
# Processing matrix 30/2904: bcsstk08
# Processing matrix 31/2904: bcsstk09
# Processing matrix 32/2904: bcsstk10
# Processing matrix 33/2904: bcsstk11
# Processing matrix 34/2904: bcsstk12
# Processing matrix 35/2904: bcsstk13
# Processing matrix 36/2904: bcsstk14
# Processing matrix 37/2904: bcsstk15
# Processing matrix 38/2904: bcsstk16
# Processing matrix 39/2904: bcsstk17
# Processing matrix 40/2904: bcsstk18
# Processing matrix 41/2904: bcsstk19
# Processing matrix 42/2904: bcsstk20
# Processing matrix 43/2904: bcsstk21
# Processing matrix 44/2904: bcsstk22
# Processing matrix 45/2904: bcsstk23
# Processing matrix 46/2904: bcsstk24
# Processing matrix 47/2904: bcsstk25
# Processing matrix 48/2904: bcsstk26
# Processing matrix 49/2904: bcsstk27
# Processing matrix 50/2904: bcsstk28
# Processing matrix 51/2904: bcsstk29
# Processing matrix 2901/2904: uni_chimera_i2
# Processing matrix 2902/2904: uni_chimera_i3
# Processing matrix 2903/2904: uni_chimera_i4
# Processing matrix 2904/2904: uni_chimera_i5
# Matrix metadata saved to ss_matrix_metadata.json

# %%
def filter_matrices(filename="ss_matrix_metadata.json", row_range=None, col_range=None, sparsity_range=None):
    
    if not os.path.exists(filename):
        print(f"Metadata file {filename} not found. Maybe run the fetch_and_store_results() first!")
        return []


    with open(filename, "r") as f:
        matrix_metadata = json.load(f)


    filtered = []
    for matrix in matrix_metadata:
        if row_range and not (row_range[0] <= matrix["rows"] <= row_range[1]):
            continue
        if col_range and not (col_range[0] <= matrix["cols"] <= col_range[1]):
            continue
        if sparsity_range and not (sparsity_range[0] <= matrix["sparsity"] <= sparsity_range[1]):
            continue
        filtered.append(matrix)

    return filtered

if __name__ == "__main__":
    
    row_range = (10000, 50000)         
    col_range = (10000, 50000)         
    sparsity_range = (0.9, 1.0) 

    metadata_file= "ss_matrix_metadata.json"

    filtered_matrices = filter_matrices(
        filename=metadata_file,
        row_range=row_range,
        col_range=col_range,
        sparsity_range=sparsity_range
    )

    
    print(f"Found {len(filtered_matrices)} matrices matching the criteria")
    for matrix in filtered_matrices:
        print(f"  Name: {matrix['name']}, Rows: {matrix['rows']}, Cols: {matrix['cols']}, Sparsity: {matrix['sparsity']:.6f}")
# Out:
# Found 503 matrices matching the criteria
#   Name: bcsstk17, Rows: 10974, Cols: 10974, Sparsity: 0.996441
#   Name: bcsstk18, Rows: 11948, Cols: 11948, Sparsity: 0.998956
#   Name: bcsstk25, Rows: 15439, Cols: 15439, Sparsity: 0.998942
#   Name: bcsstk29, Rows: 13992, Cols: 13992, Sparsity: 0.996836
#   Name: bcsstk30, Rows: 28924, Cols: 28924, Sparsity: 0.997557
#   Name: bcsstk31, Rows: 35588, Cols: 35588, Sparsity: 0.999067
#   Name: bcsstk32, Rows: 44609, Cols: 44609, Sparsity: 0.998988
#   Name: bcsstm25, Rows: 15439, Cols: 15439, Sparsity: 0.999935
#   Name: onetone1, Rows: 36057, Cols: 36057, Sparsity: 0.999742
#   Name: onetone2, Rows: 36057, Cols: 36057, Sparsity: 0.999829
#   Name: epb1, Rows: 14734, Cols: 14734, Sparsity: 0.999562
#   Name: epb2, Rows: 25228, Cols: 25228, Sparsity: 0.999725
#   Name: af23560, Rows: 23560, Cols: 23560, Sparsity: 0.999170
#   Name: bcsstk35, Rows: 30237, Cols: 30237, Sparsity: 0.998414
#   Name: bcsstk36, Rows: 23052, Cols: 23052, Sparsity: 0.997849
#   Name: bcsstk37, Rows: 25503, Cols: 25503, Sparsity: 0.998246
#   Name: bcsstm35, Rows: 30237, Cols: 30237, Sparsity: 0.999977
#   Name: bcsstm36, Rows: 23052, Cols: 23052, Sparsity: 0.999397
#   Name: bcsstm37, Rows: 25503, Cols: 25503, Sparsity: 0.999976
#   Name: bcsstm39, Rows: 46772, Cols: 46772, Sparsity: 0.999979
#   Name: crystk02, Rows: 13965, Cols: 13965, Sparsity: 0.995033
#   Name: crystk03, Rows: 24696, Cols: 24696, Sparsity: 0.997129
#   Name: crystm02, Rows: 13965, Cols: 13965, Sparsity: 0.998344
#   Name: crystm03, Rows: 24696, Cols: 24696, Sparsity: 0.999043
#   Name: msc10848, Rows: 10848, Cols: 10848, Sparsity: 0.989550
#   Name: msc23052, Rows: 23052, Cols: 23052, Sparsity: 0.997850
#   Name: pcrystk02, Rows: 13965, Cols: 13965, Sparsity: 0.995033
#   Name: pcrystk03, Rows: 24696, Cols: 24696, Sparsity: 0.997129
#   Name: circuit_3, Rows: 12127, Cols: 12127, Sparsity: 0.999673
#   Name: rma10, Rows: 46835, Cols: 46835, Sparsity: 0.998938
#   Name: vibrobox, Rows: 12328, Cols: 12328, Sparsity: 0.998015
#   Name: ex11, Rows: 16614, Cols: 16614, Sparsity: 0.996026
#   Name: ex19, Rows: 12005, Cols: 12005, Sparsity: 0.998199
#   Name: ex35, Rows: 19716, Cols: 19716, Sparsity: 0.999414
#   Name: big, Rows: 13209, Cols: 13209, Sparsity: 0.999476
#   Name: nopoly, Rows: 10774, Cols: 10774, Sparsity: 0.999390
#   Name: pesa, Rows: 11738, Cols: 11738, Sparsity: 0.999423
#   Name: garon2, Rows: 13535, Cols: 13535, Sparsity: 0.997963
#   Name: rim, Rows: 22560, Cols: 22560, Sparsity: 0.998006
#   Name: bayer02, Rows: 13935, Cols: 13935, Sparsity: 0.999674
#   Name: bayer04, Rows: 20545, Cols: 20545, Sparsity: 0.999797
#   Name: bayer10, Rows: 13436, Cols: 13436, Sparsity: 0.999603
#   Name: poli_large, Rows: 15575, Cols: 15575, Sparsity: 0.999864
#   Name: G67, Rows: 10000, Cols: 10000, Sparsity: 0.999600
#   Name: gupta1, Rows: 31802, Cols: 31802, Sparsity: 0.997860
#   Name: gupta3, Rows: 16783, Cols: 16783, Sparsity: 0.966899
#   Name: memplus, Rows: 17758, Cols: 17758, Sparsity: 0.999686
#   Name: g7jac040, Rows: 11790, Cols: 11790, Sparsity: 0.999227
#   Name: g7jac040sc, Rows: 11790, Cols: 11790, Sparsity: 0.999227
#   Name: g7jac050sc, Rows: 14760, Cols: 14760, Sparsity: 0.999334
#   Name: g7jac060, Rows: 17730, Cols: 17730, Sparsity: 0.999417
#   Name: g7jac060sc, Rows: 17730, Cols: 17730, Sparsity: 0.999417
#   Name: g7jac080, Rows: 23670, Cols: 23670, Sparsity: 0.999537
#   Name: g7jac080sc, Rows: 23670, Cols: 23670, Sparsity: 0.999537
#   Name: g7jac100, Rows: 29610, Cols: 29610, Sparsity: 0.999617
#   Name: g7jac100sc, Rows: 29610, Cols: 29610, Sparsity: 0.999617
#   Name: g7jac120, Rows: 35550, Cols: 35550, Sparsity: 0.999674
#   Name: g7jac120sc, Rows: 35550, Cols: 35550, Sparsity: 0.999674
#   Name: g7jac140, Rows: 41490, Cols: 41490, Sparsity: 0.999716
#   Name: g7jac140sc, Rows: 41490, Cols: 41490, Sparsity: 0.999716
#   Name: g7jac160, Rows: 47430, Cols: 47430, Sparsity: 0.999749
#   Name: g7jac160sc, Rows: 47430, Cols: 47430, Sparsity: 0.999749
#   Name: jan99jac040, Rows: 13694, Cols: 13694, Sparsity: 0.999612
#   Name: jan99jac040sc, Rows: 13694, Cols: 13694, Sparsity: 0.999612
#   Name: jan99jac060, Rows: 20614, Cols: 20614, Sparsity: 0.999737
#   Name: jan99jac060sc, Rows: 20614, Cols: 20614, Sparsity: 0.999737
#   Name: jan99jac080, Rows: 27534, Cols: 27534, Sparsity: 0.999801
#   Name: jan99jac080sc, Rows: 27534, Cols: 27534, Sparsity: 0.999801
#   Name: jan99jac100, Rows: 34454, Cols: 34454, Sparsity: 0.999840
#   Name: jan99jac100sc, Rows: 34454, Cols: 34454, Sparsity: 0.999840
#   Name: jan99jac120, Rows: 41374, Cols: 41374, Sparsity: 0.999866
#   Name: jan99jac120sc, Rows: 41374, Cols: 41374, Sparsity: 0.999866
#   Name: mark3jac040, Rows: 18289, Cols: 18289, Sparsity: 0.999681
#   Name: mark3jac040sc, Rows: 18289, Cols: 18289, Sparsity: 0.999681
#   Name: mark3jac060, Rows: 27449, Cols: 27449, Sparsity: 0.999787
#   Name: mark3jac060sc, Rows: 27449, Cols: 27449, Sparsity: 0.999787
#   Name: mark3jac080, Rows: 36609, Cols: 36609, Sparsity: 0.999840
#   Name: mark3jac080sc, Rows: 36609, Cols: 36609, Sparsity: 0.999840
#   Name: mark3jac100, Rows: 45769, Cols: 45769, Sparsity: 0.999872
#   Name: mark3jac100sc, Rows: 45769, Cols: 45769, Sparsity: 0.999872
#   Name: lp_ken_11, Rows: 14694, Cols: 21349, Sparsity: 0.999844
#   Name: lp_ken_13, Rows: 28632, Cols: 42659, Sparsity: 0.999920
#   Name: lp_pds_10, Rows: 16558, Cols: 49932, Sparsity: 0.999870
#   Name: lp_stocfor3, Rows: 16675, Cols: 23541, Sparsity: 0.999815
#   Name: li, Rows: 22695, Cols: 22695, Sparsity: 0.997641
#   Name: pli, Rows: 22695, Cols: 22695, Sparsity: 0.997378
#   Name: lhr10, Rows: 10672, Cols: 10672, Sparsity: 0.997995
#   Name: lhr10c, Rows: 10672, Cols: 10672, Sparsity: 0.997957
#   Name: lhr11, Rows: 10964, Cols: 10964, Sparsity: 0.998072
#   Name: lhr11c, Rows: 10964, Cols: 10964, Sparsity: 0.998056
#   Name: lhr14, Rows: 14270, Cols: 14270, Sparsity: 0.998499
#   Name: lhr14c, Rows: 14270, Cols: 14270, Sparsity: 0.998488
#   Name: lhr17, Rows: 17576, Cols: 17576, Sparsity: 0.998771
#   Name: lhr17c, Rows: 17576, Cols: 17576, Sparsity: 0.998763
#   Name: lhr34, Rows: 35152, Cols: 35152, Sparsity: 0.999395
#   Name: lhr34c, Rows: 35152, Cols: 35152, Sparsity: 0.999382
#   Name: barth5, Rows: 15606, Cols: 15606, Sparsity: 0.999748
#   Name: pwt, Rows: 36519, Cols: 36519, Sparsity: 0.999755
#   Name: shuttle_eddy, Rows: 10429, Cols: 10429, Sparsity: 0.999047
#   Name: skirt, Rows: 12598, Cols: 12598, Sparsity: 0.998762
#   Name: xenon1, Rows: 48600, Cols: 48600, Sparsity: 0.999500
#   Name: 3dtube, Rows: 45330, Cols: 45330, Sparsity: 0.998436
#   Name: appu, Rows: 14000, Cols: 14000, Sparsity: 0.990545
#   Name: bbmat, Rows: 38744, Cols: 38744, Sparsity: 0.998820
#   Name: olafu, Rows: 16146, Cols: 16146, Sparsity: 0.996106
#   Name: raefsky3, Rows: 21200, Cols: 21200, Sparsity: 0.996688
#   Name: raefsky4, Rows: 19779, Cols: 19779, Sparsity: 0.996634
#   Name: av41092, Rows: 41092, Cols: 41092, Sparsity: 0.999003
#   Name: wang3, Rows: 26064, Cols: 26064, Sparsity: 0.999739
#   Name: wang4, Rows: 26068, Cols: 26068, Sparsity: 0.999739
#   Name: Zhao1, Rows: 33861, Cols: 33861, Sparsity: 0.999855
#   Name: Zhao2, Rows: 33861, Cols: 33861, Sparsity: 0.999855
#   Name: k3plates, Rows: 11107, Cols: 11107, Sparsity: 0.996928
#   Name: m3plates, Rows: 11107, Cols: 11107, Sparsity: 0.999946
#   Name: bcsstk39, Rows: 46772, Cols: 46772, Sparsity: 0.999058
#   Name: pkustk01, Rows: 22044, Cols: 22044, Sparsity: 0.997985
#   Name: pkustk02, Rows: 10800, Cols: 10800, Sparsity: 0.993056
#   Name: pkustk05, Rows: 37164, Cols: 37164, Sparsity: 0.998403
#   Name: pkustk06, Rows: 43164, Cols: 43164, Sparsity: 0.998620
#   Name: pkustk07, Rows: 16860, Cols: 16860, Sparsity: 0.991491
#   Name: pkustk08, Rows: 22209, Cols: 22209, Sparsity: 0.993458
#   Name: pkustk09, Rows: 33960, Cols: 33960, Sparsity: 0.998627
#   Name: kim1, Rows: 38415, Cols: 38415, Sparsity: 0.999368
#   Name: barth5, Rows: 15606, Cols: 15606, Sparsity: 0.999559
#   Name: bodyy4, Rows: 17546, Cols: 17546, Sparsity: 0.999605
#   Name: bodyy5, Rows: 18589, Cols: 18589, Sparsity: 0.999627
#   Name: bodyy6, Rows: 19366, Cols: 19366, Sparsity: 0.999642
#   Name: pwt, Rows: 36519, Cols: 36519, Sparsity: 0.999755
#   Name: shuttle_eddy, Rows: 10429, Cols: 10429, Sparsity: 0.999047
#   Name: skirt, Rows: 12598, Cols: 12598, Sparsity: 0.998762
#   Name: tandem_vtx, Rows: 18454, Cols: 18454, Sparsity: 0.999256
#   Name: e40r0100, Rows: 17281, Cols: 17281, Sparsity: 0.998146
#   Name: shermanACb, Rows: 18510, Cols: 18510, Sparsity: 0.999576
#   Name: cage10, Rows: 11397, Cols: 11397, Sparsity: 0.998840
#   Name: cage11, Rows: 39082, Cols: 39082, Sparsity: 0.999634
#   Name: fd15, Rows: 11532, Cols: 11532, Sparsity: 0.999668
#   Name: fd18, Rows: 16428, Cols: 16428, Sparsity: 0.999765
#   Name: sinc15, Rows: 11532, Cols: 11532, Sparsity: 0.995855
#   Name: sinc18, Rows: 16428, Cols: 16428, Sparsity: 0.996485
#   Name: ns3Da, Rows: 20414, Cols: 20414, Sparsity: 0.995970
#   Name: poisson3Da, Rows: 13514, Cols: 13514, Sparsity: 0.998068
#   Name: sme3Da, Rows: 12504, Cols: 12504, Sparsity: 0.994404
#   Name: sme3Db, Rows: 29067, Cols: 29067, Sparsity: 0.997537
#   Name: sme3Dc, Rows: 42930, Cols: 42930, Sparsity: 0.998292
#   Name: waveguide3D, Rows: 21036, Cols: 21036, Sparsity: 0.999314
#   Name: nd6k, Rows: 18000, Cols: 18000, Sparsity: 0.978712
#   Name: nd12k, Rows: 36000, Cols: 36000, Sparsity: 0.989027
#   Name: c-62, Rows: 41731, Cols: 41731, Sparsity: 0.999679
#   Name: c-66, Rows: 49989, Cols: 49989, Sparsity: 0.999822
#   Name: 2D_27628_bjtcai, Rows: 27628, Cols: 27628, Sparsity: 0.999729
#   Name: 3D_28984_Tetra, Rows: 28984, Cols: 28984, Sparsity: 0.999661
#   Name: igbt3, Rows: 10938, Cols: 10938, Sparsity: 0.998909
#   Name: nmos3, Rows: 18588, Cols: 18588, Sparsity: 0.999314
#   Name: graphics, Rows: 29493, Cols: 11822, Sparsity: 0.999662
#   Name: mult_dcop_01, Rows: 25187, Cols: 25187, Sparsity: 0.999695
#   Name: mult_dcop_02, Rows: 25187, Cols: 25187, Sparsity: 0.999695
#   Name: mult_dcop_03, Rows: 25187, Cols: 25187, Sparsity: 0.999695
#   Name: coupled, Rows: 11341, Cols: 11341, Sparsity: 0.999244
#   Name: Pres_Poisson, Rows: 14822, Cols: 14822, Sparsity: 0.996742
#   Name: rajat06, Rows: 10922, Cols: 10922, Sparsity: 0.999606
#   Name: rajat07, Rows: 14842, Cols: 14842, Sparsity: 0.999710
#   Name: rajat08, Rows: 19362, Cols: 19362, Sparsity: 0.999777
#   Name: rajat09, Rows: 24482, Cols: 24482, Sparsity: 0.999824
#   Name: rajat10, Rows: 30202, Cols: 30202, Sparsity: 0.999857
#   Name: gyro_k, Rows: 17361, Cols: 17361, Sparsity: 0.996612
#   Name: gyro_m, Rows: 17361, Cols: 17361, Sparsity: 0.998871
#   Name: t2dah_a, Rows: 11445, Cols: 11445, Sparsity: 0.998655
#   Name: t2dah_e, Rows: 11445, Cols: 11445, Sparsity: 0.998655
#   Name: t3dl_a, Rows: 20360, Cols: 20360, Sparsity: 0.998770
#   Name: t3dl_e, Rows: 20360, Cols: 20360, Sparsity: 0.999951
#   Name: powersim, Rows: 15838, Cols: 15838, Sparsity: 0.999743
#   Name: aug2d, Rows: 29008, Cols: 29008, Sparsity: 0.999909
#   Name: aug2dc, Rows: 30200, Cols: 30200, Sparsity: 0.999912
#   Name: aug3d, Rows: 24300, Cols: 24300, Sparsity: 0.999881
#   Name: aug3dcqp, Rows: 35543, Cols: 35543, Sparsity: 0.999899
#   Name: c-55, Rows: 32780, Cols: 32780, Sparsity: 0.999625
#   Name: c-58, Rows: 37595, Cols: 37595, Sparsity: 0.999609
#   Name: c-59, Rows: 41282, Cols: 41282, Sparsity: 0.999718
#   Name: c-62ghs, Rows: 41731, Cols: 41731, Sparsity: 0.999679
#   Name: c-63, Rows: 44234, Cols: 44234, Sparsity: 0.999778
#   Name: dtoc, Rows: 24993, Cols: 24993, Sparsity: 0.999888
#   Name: helm3d01, Rows: 32226, Cols: 32226, Sparsity: 0.999587
#   Name: mario001, Rows: 38434, Cols: 38434, Sparsity: 0.999861
#   Name: ncvxqp1, Rows: 12111, Cols: 12111, Sparsity: 0.999496
#   Name: ncvxqp9, Rows: 16554, Cols: 16554, Sparsity: 0.999803
#   Name: sit100, Rows: 10262, Cols: 10262, Sparsity: 0.999420
#   Name: stokes128, Rows: 49666, Cols: 49666, Sparsity: 0.999774
#   Name: stokes64, Rows: 12546, Cols: 12546, Sparsity: 0.999110
#   Name: stokes64s, Rows: 12546, Cols: 12546, Sparsity: 0.999110
#   Name: tuma1, Rows: 22967, Cols: 22967, Sparsity: 0.999834
#   Name: tuma2, Rows: 12992, Cols: 12992, Sparsity: 0.999708
#   Name: copter1, Rows: 17222, Cols: 17222, Sparsity: 0.999288
#   Name: crplat2, Rows: 18010, Cols: 18010, Sparsity: 0.997037
#   Name: finance256, Rows: 37376, Cols: 37376, Sparsity: 0.999786
#   Name: ford1, Rows: 18728, Cols: 18728, Sparsity: 0.999710
#   Name: opt1, Rows: 15449, Cols: 15449, Sparsity: 0.991911
#   Name: pds10, Rows: 16558, Cols: 16558, Sparsity: 0.999454
#   Name: pwt, Rows: 36519, Cols: 36519, Sparsity: 0.999755
#   Name: ramage02, Rows: 16830, Cols: 16830, Sparsity: 0.989880
#   Name: ship_001, Rows: 34920, Cols: 34920, Sparsity: 0.996805
#   Name: thread, Rows: 29736, Cols: 29736, Sparsity: 0.994973
#   Name: trdheim, Rows: 22098, Cols: 22098, Sparsity: 0.996037
#   Name: tsyl201, Rows: 20685, Cols: 20685, Sparsity: 0.994262
#   Name: vanbody, Rows: 47072, Cols: 47072, Sparsity: 0.998949
#   Name: wathen100, Rows: 30401, Cols: 30401, Sparsity: 0.999490
#   Name: wathen120, Rows: 36441, Cols: 36441, Sparsity: 0.999574
#   Name: bloweya, Rows: 30004, Cols: 30004, Sparsity: 0.999833
#   Name: brainpc2, Rows: 27607, Cols: 27607, Sparsity: 0.999765
#   Name: bratu3d, Rows: 27792, Cols: 27792, Sparsity: 0.999775
#   Name: linverse, Rows: 11999, Cols: 11999, Sparsity: 0.999333
#   Name: ncvxbqp1, Rows: 50000, Cols: 50000, Sparsity: 0.999860
#   Name: sparsine, Rows: 50000, Cols: 50000, Sparsity: 0.999380
#   Name: spmsrtls, Rows: 29995, Cols: 29995, Sparsity: 0.999744
#   Name: cvxbqp1, Rows: 50000, Cols: 50000, Sparsity: 0.999860
#   Name: gridgena, Rows: 48962, Cols: 48962, Sparsity: 0.999786
#   Name: jnlbrng1, Rows: 40000, Cols: 40000, Sparsity: 0.999876
#   Name: minsurfo, Rows: 40806, Cols: 40806, Sparsity: 0.999878
#   Name: obstclae, Rows: 40000, Cols: 40000, Sparsity: 0.999876
#   Name: torsion1, Rows: 40000, Cols: 40000, Sparsity: 0.999876
#   Name: rajat15, Rows: 37261, Cols: 37261, Sparsity: 0.999681
#   Name: airfoil_2d, Rows: 14214, Cols: 14214, Sparsity: 0.998715
#   Name: std1_Jac2_db, Rows: 21982, Cols: 21982, Sparsity: 0.998968
#   Name: std1_Jac2, Rows: 21982, Cols: 21982, Sparsity: 0.997417
#   Name: std1_Jac3_db, Rows: 21982, Cols: 21982, Sparsity: 0.998899
#   Name: std1_Jac3, Rows: 21982, Cols: 21982, Sparsity: 0.996988
#   Name: Zd_Jac2_db, Rows: 22835, Cols: 22835, Sparsity: 0.998703
#   Name: Zd_Jac2, Rows: 22835, Cols: 22835, Sparsity: 0.996850
#   Name: Zd_Jac3_db, Rows: 22835, Cols: 22835, Sparsity: 0.998631
#   Name: Zd_Jac3, Rows: 22835, Cols: 22835, Sparsity: 0.996326
#   Name: Zd_Jac6_db, Rows: 22835, Cols: 22835, Sparsity: 0.998727
#   Name: Zd_Jac6, Rows: 22835, Cols: 22835, Sparsity: 0.996718
#   Name: bundle1, Rows: 10581, Cols: 10581, Sparsity: 0.993115
#   Name: Si10H16, Rows: 17077, Cols: 17077, Sparsity: 0.996996
#   Name: Si5H12, Rows: 19896, Cols: 19896, Sparsity: 0.998134
#   Name: SiO, Rows: 33401, Cols: 33401, Sparsity: 0.998819
#   Name: rajat22, Rows: 39899, Cols: 39899, Sparsity: 0.999877
#   Name: rajat27, Rows: 20640, Cols: 20640, Sparsity: 0.999771
#   Name: ex3sta1, Rows: 16782, Cols: 16782, Sparsity: 0.997589
#   Name: fxm4_6, Rows: 18892, Cols: 18892, Sparsity: 0.998605
#   Name: lpl1, Rows: 32460, Cols: 32460, Sparsity: 0.999689
#   Name: net100, Rows: 29920, Cols: 29920, Sparsity: 0.997729
#   Name: net125, Rows: 36720, Cols: 36720, Sparsity: 0.998089
#   Name: net150, Rows: 43520, Cols: 43520, Sparsity: 0.998352
#   Name: net50, Rows: 16320, Cols: 16320, Sparsity: 0.996451
#   Name: net75, Rows: 23120, Cols: 23120, Sparsity: 0.997214
#   Name: pattern1, Rows: 19242, Cols: 19242, Sparsity: 0.974819
#   Name: ted_A, Rows: 10605, Cols: 10605, Sparsity: 0.996225
#   Name: ted_B, Rows: 10605, Cols: 10605, Sparsity: 0.998714
#   Name: ted_AB, Rows: 10605, Cols: 10605, Sparsity: 0.995355
#   Name: ted_A_unscaled, Rows: 10605, Cols: 10605, Sparsity: 0.996225
#   Name: ted_B_unscaled, Rows: 10605, Cols: 10605, Sparsity: 0.998714
#   Name: ted_AB_unscaled, Rows: 10605, Cols: 10605, Sparsity: 0.995355
#   Name: ckt11752_dc_1, Rows: 49702, Cols: 49702, Sparsity: 0.999865
#   Name: ckt11752_tr_0, Rows: 49702, Cols: 49702, Sparsity: 0.999865
#   Name: bloweybl, Rows: 30003, Cols: 30003, Sparsity: 0.999878
#   Name: bloweybq, Rows: 10001, Cols: 10001, Sparsity: 0.999500
#   Name: cvxqp3, Rows: 17500, Cols: 17500, Sparsity: 0.999625
#   Name: qpband, Rows: 20000, Cols: 20000, Sparsity: 0.999888
#   Name: chipcool0, Rows: 20082, Cols: 20082, Sparsity: 0.999303
#   Name: chipcool1, Rows: 20082, Cols: 20082, Sparsity: 0.999303
#   Name: gyro, Rows: 17361, Cols: 17361, Sparsity: 0.996612
#   Name: inlet, Rows: 11730, Cols: 11730, Sparsity: 0.997614
#   Name: LF10000, Rows: 19998, Cols: 19998, Sparsity: 0.999750
#   Name: LFAT5000, Rows: 19994, Cols: 19994, Sparsity: 0.999800
#   Name: rail_20209, Rows: 20209, Cols: 20209, Sparsity: 0.999659
#   Name: t2dah, Rows: 11445, Cols: 11445, Sparsity: 0.998655
#   Name: t3dl, Rows: 20360, Cols: 20360, Sparsity: 0.998770
#   Name: windscreen, Rows: 22692, Cols: 22692, Sparsity: 0.997121
#   Name: EAT_RS, Rows: 23219, Cols: 23219, Sparsity: 0.999396
#   Name: EAT_SR, Rows: 23219, Cols: 23219, Sparsity: 0.999396
#   Name: FA, Rows: 10617, Cols: 10617, Sparsity: 0.999360
#   Name: foldoc, Rows: 13356, Cols: 13356, Sparsity: 0.999326
#   Name: HEP-th, Rows: 27240, Cols: 27240, Sparsity: 0.999539
#   Name: HEP-th-new, Rows: 27770, Cols: 27770, Sparsity: 0.999543
#   Name: Reuters911, Rows: 13332, Cols: 13332, Sparsity: 0.998334
#   Name: c-42, Rows: 10471, Cols: 10471, Sparsity: 0.998994
#   Name: c-43, Rows: 11125, Cols: 11125, Sparsity: 0.999001
#   Name: c-44, Rows: 10728, Cols: 10728, Sparsity: 0.999261
#   Name: c-45, Rows: 13206, Cols: 13206, Sparsity: 0.999000
#   Name: c-46, Rows: 14913, Cols: 14913, Sparsity: 0.999414
#   Name: c-47, Rows: 15343, Cols: 15343, Sparsity: 0.999102
#   Name: c-48, Rows: 18354, Cols: 18354, Sparsity: 0.999507
#   Name: c-49, Rows: 21132, Cols: 21132, Sparsity: 0.999648
#   Name: c-50, Rows: 22401, Cols: 22401, Sparsity: 0.999641
#   Name: c-51, Rows: 23196, Cols: 23196, Sparsity: 0.999623
#   Name: c-52, Rows: 23948, Cols: 23948, Sparsity: 0.999647
#   Name: c-53, Rows: 30235, Cols: 30235, Sparsity: 0.999612
#   Name: c-54, Rows: 31793, Cols: 31793, Sparsity: 0.999618
#   Name: c-56, Rows: 35910, Cols: 35910, Sparsity: 0.999705
#   Name: c-57, Rows: 37833, Cols: 37833, Sparsity: 0.999718
#   Name: c-60, Rows: 43640, Cols: 43640, Sparsity: 0.999843
#   Name: c-61, Rows: 43618, Cols: 43618, Sparsity: 0.999837
#   Name: c-65, Rows: 48066, Cols: 48066, Sparsity: 0.999844
#   Name: c-66b, Rows: 49989, Cols: 49989, Sparsity: 0.999822
#   Name: conf5_4-8x8-05, Rows: 49152, Cols: 49152, Sparsity: 0.999207
#   Name: conf5_4-8x8-10, Rows: 49152, Cols: 49152, Sparsity: 0.999207
#   Name: conf5_4-8x8-15, Rows: 49152, Cols: 49152, Sparsity: 0.999207
#   Name: conf5_4-8x8-20, Rows: 49152, Cols: 49152, Sparsity: 0.999207
#   Name: conf6_0-8x8-20, Rows: 49152, Cols: 49152, Sparsity: 0.999207
#   Name: conf6_0-8x8-30, Rows: 49152, Cols: 49152, Sparsity: 0.999207
#   Name: conf6_0-8x8-80, Rows: 49152, Cols: 49152, Sparsity: 0.999207
#   Name: cryg10000, Rows: 10000, Cols: 10000, Sparsity: 0.999503
#   Name: invextr1_new, Rows: 30412, Cols: 30412, Sparsity: 0.998060
#   Name: mixtank_new, Rows: 29957, Cols: 29957, Sparsity: 0.997782
#   Name: nug08-3rd, Rows: 19728, Cols: 29856, Sparsity: 0.999748
#   Name: fome11, Rows: 12142, Cols: 24460, Sparsity: 0.999760
#   Name: fome12, Rows: 24284, Cols: 48920, Sparsity: 0.999880
#   Name: baxter, Rows: 27441, Cols: 30733, Sparsity: 0.999868
#   Name: car4, Rows: 16384, Cols: 33052, Sparsity: 0.999882
#   Name: co9, Rows: 10789, Cols: 22924, Sparsity: 0.999557
#   Name: dbir1, Rows: 18804, Cols: 45775, Sparsity: 0.998749
#   Name: dbir2, Rows: 18906, Cols: 45877, Sparsity: 0.998665
#   Name: e18, Rows: 24617, Cols: 38602, Sparsity: 0.999835
#   Name: ex3sta1, Rows: 17443, Cols: 17516, Sparsity: 0.999775
#   Name: ge, Rows: 10099, Cols: 16369, Sparsity: 0.999729
#   Name: lpl3, Rows: 10828, Cols: 33686, Sparsity: 0.999724
#   Name: p010, Rows: 10090, Cols: 19090, Sparsity: 0.999387
#   Name: route, Rows: 20894, Cols: 43019, Sparsity: 0.999770
#   Name: south31, Rows: 18425, Cols: 36321, Sparsity: 0.999832
#   Name: testbig, Rows: 17613, Cols: 31223, Sparsity: 0.999888
#   Name: fxm4_6, Rows: 22400, Cols: 47185, Sparsity: 0.999749
#   Name: stormg2-27, Rows: 14441, Cols: 37485, Sparsity: 0.999826
#   Name: ts-palko, Rows: 22002, Cols: 47235, Sparsity: 0.998964
#   Name: nsct, Rows: 23003, Cols: 37563, Sparsity: 0.999192
#   Name: scagr7-2r, Rows: 32847, Cols: 46679, Sparsity: 0.999922
#   Name: scfxm1-2b, Rows: 19036, Cols: 33047, Sparsity: 0.999823
#   Name: scrs8-2r, Rows: 14364, Cols: 27691, Sparsity: 0.999853
#   Name: sctap1-2b, Rows: 15390, Cols: 33858, Sparsity: 0.999809
#   Name: Dubcova1, Rows: 16129, Cols: 16129, Sparsity: 0.999027
#   Name: FEM_3D_thermal1, Rows: 17880, Cols: 17880, Sparsity: 0.998653
#   Name: chem_master1, Rows: 40401, Cols: 40401, Sparsity: 0.999877
#   Name: Ill_Stokes, Rows: 20896, Cols: 20896, Sparsity: 0.999562
#   Name: viscoplastic2, Rows: 32769, Cols: 32769, Sparsity: 0.999645
#   Name: psse0, Rows: 26722, Cols: 11028, Sparsity: 0.999652
#   Name: psse1, Rows: 14318, Cols: 11028, Sparsity: 0.999637
#   Name: psse2, Rows: 28634, Cols: 11028, Sparsity: 0.999635
#   Name: light_in_tissue, Rows: 29282, Cols: 29282, Sparsity: 0.999526
#   Name: hvdc1, Rows: 24842, Cols: 24842, Sparsity: 0.999743
#   Name: viscorocks, Rows: 37762, Cols: 37762, Sparsity: 0.999205
#   Name: Maragal_6, Rows: 21255, Cols: 10152, Sparsity: 0.997508
#   Name: Maragal_7, Rows: 46845, Cols: 26564, Sparsity: 0.999035
#   Name: smt, Rows: 25710, Cols: 25710, Sparsity: 0.994327
#   Name: cbuckle, Rows: 13681, Cols: 13681, Sparsity: 0.996386
#   Name: cyl6, Rows: 13681, Cols: 13681, Sparsity: 0.996184
#   Name: tube1, Rows: 21498, Cols: 21498, Sparsity: 0.998059
#   Name: tube2, Rows: 21498, Cols: 21498, Sparsity: 0.998059
#   Name: TF16, Rows: 15437, Cols: 19321, Sparsity: 0.999275
#   Name: TF17, Rows: 38132, Cols: 48630, Sparsity: 0.999684
#   Name: Franz11, Rows: 47104, Cols: 30144, Sparsity: 0.999768
#   Name: IG5-15, Rows: 11369, Cols: 11987, Sparsity: 0.997626
#   Name: IG5-16, Rows: 18846, Cols: 18485, Sparsity: 0.998311
#   Name: IG5-17, Rows: 30162, Cols: 27944, Sparsity: 0.998772
#   Name: IG5-18, Rows: 47894, Cols: 41550, Sparsity: 0.999100
#   Name: ch7-6-b4, Rows: 15120, Cols: 12600, Sparsity: 0.999603
#   Name: mk11-b4, Rows: 10395, Cols: 17325, Sparsity: 0.999711
#   Name: case39, Rows: 40216, Cols: 40216, Sparsity: 0.999356
#   Name: cat_ears_4_4, Rows: 19020, Cols: 44448, Sparsity: 0.999843
#   Name: kneser_8_3_1, Rows: 15737, Cols: 15681, Sparsity: 0.999809
#   Name: Trefethen_20000b, Rows: 19999, Cols: 19999, Sparsity: 0.998614
#   Name: Trefethen_20000, Rows: 20000, Cols: 20000, Sparsity: 0.998614
#   Name: case9, Rows: 14454, Cols: 14454, Sparsity: 0.999292
#   Name: TSOPF_RS_b2383, Rows: 38120, Cols: 38120, Sparsity: 0.988872
#   Name: TSOPF_FS_b300, Rows: 29214, Cols: 29214, Sparsity: 0.994844
#   Name: TSOPF_FS_b162_c1, Rows: 10798, Cols: 10798, Sparsity: 0.994781
#   Name: TSOPF_FS_b162_c3, Rows: 30798, Cols: 30798, Sparsity: 0.998101
#   Name: TSOPF_FS_b162_c4, Rows: 40798, Cols: 40798, Sparsity: 0.998559
#   Name: TSOPF_FS_b300_c1, Rows: 29214, Cols: 29214, Sparsity: 0.994844
#   Name: TSOPF_FS_b39_c7, Rows: 28216, Cols: 28216, Sparsity: 0.999083
#   Name: TSOPF_FS_b9_c6, Rows: 14454, Cols: 14454, Sparsity: 0.999292
#   Name: TSOPF_RS_b162_c3, Rows: 15374, Cols: 15374, Sparsity: 0.997418
#   Name: TSOPF_RS_b162_c4, Rows: 20374, Cols: 20374, Sparsity: 0.998042
#   Name: TSOPF_RS_b2052_c1, Rows: 25626, Cols: 25626, Sparsity: 0.989704
#   Name: TSOPF_RS_b2383_c1, Rows: 38120, Cols: 38120, Sparsity: 0.988872
#   Name: TSOPF_RS_b300_c1, Rows: 14538, Cols: 14538, Sparsity: 0.993024
#   Name: TSOPF_RS_b300_c2, Rows: 28338, Cols: 28338, Sparsity: 0.996334
#   Name: TSOPF_RS_b300_c3, Rows: 42138, Cols: 42138, Sparsity: 0.997514
#   Name: TSOPF_RS_b39_c19, Rows: 38098, Cols: 38098, Sparsity: 0.999529
#   Name: TSOPF_RS_b39_c7, Rows: 14098, Cols: 14098, Sparsity: 0.998730
#   Name: TSOPF_RS_b678_c1, Rows: 18696, Cols: 18696, Sparsity: 0.987423
#   Name: TSOPF_RS_b678_c2, Rows: 35696, Cols: 35696, Sparsity: 0.993108
#   Name: 192bit, Rows: 13691, Cols: 13682, Sparsity: 0.999176
#   Name: 208bit, Rows: 24430, Cols: 24421, Sparsity: 0.999498
#   Name: ABACUS_shell_ud, Rows: 23412, Cols: 23412, Sparsity: 0.999601
#   Name: ABACUS_shell_ld, Rows: 23412, Cols: 23412, Sparsity: 0.999601
#   Name: ABACUS_shell_md, Rows: 23412, Cols: 23412, Sparsity: 0.999601
#   Name: ABACUS_shell_hd, Rows: 23412, Cols: 23412, Sparsity: 0.999601
#   Name: poli3, Rows: 16955, Cols: 16955, Sparsity: 0.999868
#   Name: poli4, Rows: 33833, Cols: 33833, Sparsity: 0.999936
#   Name: human_gene1, Rows: 22283, Cols: 22283, Sparsity: 0.950316
#   Name: human_gene2, Rows: 14340, Cols: 14340, Sparsity: 0.912134
#   Name: mouse_gene, Rows: 45101, Cols: 45101, Sparsity: 0.985759
#   Name: email-Enron, Rows: 36692, Cols: 36692, Sparsity: 0.999727
#   Name: cit-HepPh, Rows: 34546, Cols: 34546, Sparsity: 0.999647
#   Name: cit-HepTh, Rows: 27770, Cols: 27770, Sparsity: 0.999543
#   Name: ca-AstroPh, Rows: 18772, Cols: 18772, Sparsity: 0.998876
#   Name: ca-CondMat, Rows: 23133, Cols: 23133, Sparsity: 0.999651
#   Name: ca-HepPh, Rows: 12008, Cols: 12008, Sparsity: 0.998356
#   Name: p2p-Gnutella04, Rows: 10879, Cols: 10879, Sparsity: 0.999662
#   Name: p2p-Gnutella24, Rows: 26518, Cols: 26518, Sparsity: 0.999907
#   Name: p2p-Gnutella25, Rows: 22687, Cols: 22687, Sparsity: 0.999894
#   Name: p2p-Gnutella30, Rows: 36682, Cols: 36682, Sparsity: 0.999934
#   Name: as-caida, Rows: 31379, Cols: 31379, Sparsity: 0.999892
#   Name: Oregon-1, Rows: 11492, Cols: 11492, Sparsity: 0.999645
#   Name: Oregon-2, Rows: 11806, Cols: 11806, Sparsity: 0.999530
#   Name: ww_vref_6405, Rows: 13251, Cols: 13251, Sparsity: 0.999722
#   Name: xingo_afonso_itaipu, Rows: 13250, Cols: 13250, Sparsity: 0.999722
#   Name: mimo8x8_system, Rows: 13309, Cols: 13309, Sparsity: 0.999724
#   Name: mimo28x28_system, Rows: 13251, Cols: 13251, Sparsity: 0.999722
#   Name: mimo46x46_system, Rows: 13250, Cols: 13250, Sparsity: 0.999722
#   Name: juba40k, Rows: 40337, Cols: 40337, Sparsity: 0.999911
#   Name: bauru5727, Rows: 40366, Cols: 40366, Sparsity: 0.999911
#   Name: zeros_nopss_13k, Rows: 13296, Cols: 13296, Sparsity: 0.999724
#   Name: descriptor_xingo6u, Rows: 20738, Cols: 20738, Sparsity: 0.999828
#   Name: nopss_11k, Rows: 11685, Cols: 11685, Sparsity: 0.999671
#   Name: xingo3012, Rows: 20944, Cols: 20944, Sparsity: 0.999830
#   Name: bips98_1450, Rows: 11305, Cols: 11305, Sparsity: 0.999650
#   Name: bips07_1693, Rows: 13275, Cols: 13275, Sparsity: 0.999722
#   Name: bips07_1998, Rows: 15066, Cols: 15066, Sparsity: 0.999726
#   Name: bips07_2476, Rows: 16861, Cols: 16861, Sparsity: 0.999766
#   Name: bips07_3078, Rows: 21128, Cols: 21128, Sparsity: 0.999830
#   Name: pdb1HYS, Rows: 36417, Cols: 36417, Sparsity: 0.996724
#   Name: as-22july06, Rows: 22963, Cols: 22963, Sparsity: 0.999816
#   Name: astro-ph, Rows: 16706, Cols: 16706, Sparsity: 0.999131
#   Name: cond-mat, Rows: 16726, Cols: 16726, Sparsity: 0.999660
#   Name: cond-mat-2003, Rows: 31163, Cols: 31163, Sparsity: 0.999753
#   Name: cond-mat-2005, Rows: 40421, Cols: 40421, Sparsity: 0.999785
#   Name: PGPgiantcompo, Rows: 10680, Cols: 10680, Sparsity: 0.999574
#   Name: big_dual, Rows: 30269, Cols: 30269, Sparsity: 0.999902
#   Name: crack, Rows: 10240, Cols: 10240, Sparsity: 0.999421
#   Name: crack_dual, Rows: 20141, Cols: 20141, Sparsity: 0.999852
#   Name: whitaker3_dual, Rows: 19190, Cols: 19190, Sparsity: 0.999845
#   Name: L-9, Rows: 17983, Cols: 17983, Sparsity: 0.999780
#   Name: stufe-10, Rows: 24010, Cols: 24010, Sparsity: 0.999839
#   Name: biplane-9, Rows: 21701, Cols: 21701, Sparsity: 0.999821
#   Name: shock-9, Rows: 36476, Cols: 36476, Sparsity: 0.999893
#   Name: bfly, Rows: 49152, Cols: 49152, Sparsity: 0.999919
#   Name: cca, Rows: 49152, Cols: 49152, Sparsity: 0.999942
#   Name: ccc, Rows: 49152, Cols: 49152, Sparsity: 0.999939
#   Name: se, Rows: 32768, Cols: 32768, Sparsity: 0.999908
#   Name: delaunay_n14, Rows: 16384, Cols: 16384, Sparsity: 0.999634
#   Name: delaunay_n15, Rows: 32768, Cols: 32768, Sparsity: 0.999817
#   Name: rgg_n_2_15_s0, Rows: 32768, Cols: 32768, Sparsity: 0.999702
#   Name: cs4, Rows: 22499, Cols: 22499, Sparsity: 0.999827
#   Name: cti, Rows: 16840, Cols: 16840, Sparsity: 0.999660
#   Name: fe_4elt2, Rows: 11143, Cols: 11143, Sparsity: 0.999471
#   Name: fe_body, Rows: 45087, Cols: 45087, Sparsity: 0.999839
#   Name: fe_sphere, Rows: 16386, Cols: 16386, Sparsity: 0.999634
#   Name: wing_nodal, Rows: 10937, Cols: 10937, Sparsity: 0.998738
#   Name: OPF_10000, Rows: 43887, Cols: 43887, Sparsity: 0.999778
#   Name: OPF_3754, Rows: 15435, Cols: 15435, Sparsity: 0.999406
#   Name: OPF_6000, Rows: 29902, Cols: 29902, Sparsity: 0.999693
#   Name: N_reactome, Rows: 10204, Cols: 16559, Sparsity: 0.999741
#   Name: Chevron1, Rows: 37365, Cols: 37365, Sparsity: 0.999763
#   Name: cz10228, Rows: 10228, Cols: 10228, Sparsity: 0.999017
#   Name: cz20468, Rows: 20468, Cols: 20468, Sparsity: 0.999508
#   Name: cz40948, Rows: 40948, Cols: 40948, Sparsity: 0.999754
#   Name: CurlCurl_0, Rows: 11083, Cols: 11083, Sparsity: 0.999077
#   Name: ak2010, Rows: 45292, Cols: 45292, Sparsity: 0.999894
#   Name: de2010, Rows: 24115, Cols: 24115, Sparsity: 0.999800
#   Name: hi2010, Rows: 25016, Cols: 25016, Sparsity: 0.999802
#   Name: nh2010, Rows: 48837, Cols: 48837, Sparsity: 0.999902
#   Name: ri2010, Rows: 25181, Cols: 25181, Sparsity: 0.999802
#   Name: vt2010, Rows: 32580, Cols: 32580, Sparsity: 0.999853
#   Name: vsp_barth5_1Ksep_50in_5Kout, Rows: 32212, Cols: 32212, Sparsity: 0.999804
#   Name: vsp_befref_fxm_2_4_air02, Rows: 14109, Cols: 14109, Sparsity: 0.999013
#   Name: vsp_c-30_data_data, Rows: 11023, Cols: 11023, Sparsity: 0.998976
#   Name: vsp_model1_crew1_cr42_south31, Rows: 45101, Cols: 45101, Sparsity: 0.999813
#   Name: vsp_msc10848_300sep_100in_1Kout, Rows: 21996, Cols: 21996, Sparsity: 0.994953
#   Name: vsp_p0291_seymourl_iiasa, Rows: 10498, Cols: 10498, Sparsity: 0.999022
#   Name: vsp_sctap1-2b_and_seymourl, Rows: 40174, Cols: 40174, Sparsity: 0.999825
#   Name: vsp_south31_slptsk, Rows: 39668, Cols: 39668, Sparsity: 0.999759
#   Name: hangGlider_3, Rows: 10260, Cols: 10260, Sparsity: 0.999119
#   Name: hangGlider_4, Rows: 15561, Cols: 15561, Sparsity: 0.999382
#   Name: hangGlider_5, Rows: 16011, Cols: 16011, Sparsity: 0.999394
#   Name: lowThrust_4, Rows: 13562, Cols: 13562, Sparsity: 0.999125
#   Name: lowThrust_5, Rows: 16262, Cols: 16262, Sparsity: 0.999250
#   Name: lowThrust_6, Rows: 16928, Cols: 16928, Sparsity: 0.999276
#   Name: lowThrust_7, Rows: 17378, Cols: 17378, Sparsity: 0.999299
#   Name: lowThrust_8, Rows: 17702, Cols: 17702, Sparsity: 0.999309
#   Name: lowThrust_9, Rows: 18044, Cols: 18044, Sparsity: 0.999326
#   Name: lowThrust_10, Rows: 18260, Cols: 18260, Sparsity: 0.999334
#   Name: lowThrust_11, Rows: 18368, Cols: 18368, Sparsity: 0.999337
#   Name: lowThrust_12, Rows: 18458, Cols: 18458, Sparsity: 0.999341
#   Name: lowThrust_13, Rows: 18476, Cols: 18476, Sparsity: 0.999341
#   Name: mycielskian14, Rows: 12287, Cols: 12287, Sparsity: 0.975522
#   Name: mycielskian15, Rows: 24575, Cols: 24575, Sparsity: 0.981602
#   Name: mycielskian16, Rows: 49151, Cols: 49151, Sparsity: 0.986182
#   Name: sx-mathoverflow, Rows: 24818, Cols: 24818, Sparsity: 0.999610
#   Name: wiki-RfA, Rows: 11380, Cols: 11380, Sparsity: 0.998548
#   Name: TEM27623, Rows: 27623, Cols: 27623, Sparsity: 0.999424
#   Name: windtunnel_evap3d, Rows: 40816, Cols: 40816, Sparsity: 0.999517
#   Name: Goodwin_030, Rows: 10142, Cols: 10142, Sparsity: 0.996959
#   Name: Goodwin_040, Rows: 17922, Cols: 17922, Sparsity: 0.998251
#   Name: Goodwin_054, Rows: 32510, Cols: 32510, Sparsity: 0.999025
#   Name: ACTIVSg10K, Rows: 20000, Cols: 20000, Sparsity: 0.999660
#   Name: mosfet2, Rows: 46994, Cols: 46994, Sparsity: 0.999541
#   Name: Fashion_MNIST_norm_10NN, Rows: 10000, Cols: 10000, Sparsity: 0.998417
#   Name: har_10NN, Rows: 10299, Cols: 10299, Sparsity: 0.998569
#   Name: k49_norm_10NN, Rows: 38547, Cols: 38547, Sparsity: 0.999584
#   Name: kmnist_norm_10NN, Rows: 10000, Cols: 10000, Sparsity: 0.998431
#   Name: mnist_test_norm_10NN, Rows: 10000, Cols: 10000, Sparsity: 0.998544
#   Name: usps_norm_5NN, Rows: 11000, Cols: 11000, Sparsity: 0.999330
#   Name: worms20_10NN, Rows: 20055, Cols: 20055, Sparsity: 0.999401

# %%
import ssgetpy
from IPython.display import display
import matplotlib.pyplot as plt
from scipy.io import mmread

# List of matrix names
matrix_names = ['1138_bus', 'bcsstk01', 'bcspwr01']  # Add more names as needed

# Collect all matrices
all_matrices = []

for name in matrix_names:
    results = ssgetpy.search(name=name)  # Perform search for each name
    all_matrices.extend(results)  # Add results to the list

# Display metadata and spy plots
for matrix in all_matrices:
    display(matrix)  # Display metadata and spy plot for each matrix
# Out:
# Matrix(1, 'HB', '1138_bus', 1138, 1138, 4054, 'real', False, True, 1.0, 1.0, 'power network problem', 'https://sparse.tamu.edu/files/HB/1138_bus.png')
# Matrix(23, 'HB', 'bcsstk01', 48, 48, 400, 'real', True, True, 1.0, 1.0, 'structural problem', 'https://sparse.tamu.edu/files/HB/bcsstk01.png')
# Matrix(13, 'HB', 'bcspwr01', 39, 39, 131, 'binary', False, False, 1.0, 1.0, 'power network problem', 'https://sparse.tamu.edu/files/HB/bcspwr01.png')

# %%
import ssgetpy
from IPython.display import display
import matplotlib.pyplot as plt
from scipy.io import mmread

# List of matrix names
matrix_names = ['1138_bus', 'bcsstk01', 'bcspwr01']  # Add more names as needed

matrix= ssgetpy.search(name= matrix_names[0])
display(matrix)

print("Download business")

dest_dir = "../ssmatrices"

matrix.download(format= 'MM', destpath= dest_dir, extract= True)
# Out:
# [Matrix(1, 'HB', '1138_bus', 1138, 1138, 4054, 'real', False, True, 1.0, 1.0, 'power network problem', 'https://sparse.tamu.edu/files/HB/1138_bus.png')]
# Download business
# Overall progress:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import os
import shutil
import json
import ssgetpy

def filter_matrices(filename, row_range=None, col_range=None, sparsity_range=None):
    """
    Filter matrices based on the row, column, and sparsity range.
    
    Parameters:
        filename (str): Path to the metadata file.
        row_range (tuple): Min and max number of rows.
        col_range (tuple): Min and max number of columns.
        sparsity_range (tuple): Min and max sparsity.

    Returns:
        list: Filtered matrix metadata.
    """
    if not os.path.exists(filename):
        print(f"Metadata file {filename} not found. Maybe run the fetch_and_store_results() first!")
        return []

    with open(filename, "r") as f:
        matrix_metadata = json.load(f)

    filtered = []
    for matrix in matrix_metadata:
        if row_range and not (row_range[0] <= matrix["rows"] <= row_range[1]):
            continue
        if col_range and not (col_range[0] <= matrix["cols"] <= col_range[1]):
            continue
        if sparsity_range and not (sparsity_range[0] <= matrix["sparsity"] <= sparsity_range[1]):
            continue
        filtered.append(matrix)

    return filtered

def download_and_save_matrices(filtered_matrices, dest_dir):
    """
    Download filtered matrices and save their .mtx files directly to the destination directory.
    
    Parameters:
        filtered_matrices (list): List of filtered matrix metadata.
        dest_dir (str): Path to the directory where the .mtx files should be saved.
    """

    for matrix_meta in filtered_matrices:
        matrix_name = matrix_meta["name"]
        print(f"Downloading matrix: {matrix_name}")
        try:
            matrix = ssgetpy.search(name=matrix_name,limit=10)[0]  # Search for the matrix
            download_path, extract_path = matrix.download(format='MM', destpath=dest_dir, extract=True)  # Download matrix
            
            # Find and move .mtx file
            extracted_dir = os.path.join(dest_dir, matrix_name)
            mtx_files = [f for f in os.listdir(extracted_dir) if f.endswith('.mtx')]

            if not mtx_files:
                print(f"No .mtx file found for matrix: {matrix_name}")
                continue

            mtx_file = mtx_files[0]
            shutil.move(os.path.join(extracted_dir, mtx_file), os.path.join(dest_dir, mtx_file))

            # Remove the now-empty extracted folder
            shutil.rmtree(extracted_dir)
            print(f"Matrix '{matrix_name}' saved as: {mtx_file}")
        except Exception as e:
            print(f"Error downloading matrix '{matrix_name}': {e}")

if __name__ == "__main__":
    # Define filtering criteria
    row_range = (10000, 50000)         
    col_range = (10000, 50000)         
    sparsity_range = (0.9, 1.0) 

    metadata_file = "../ssmatrices/ss_matrix_metadata.json"
    dest_dir = "../ssmatrices"

    # Filter matrices
    filtered_matrices = filter_matrices(
        filename=metadata_file,
        row_range=row_range,
        col_range=col_range,
        sparsity_range=sparsity_range
    )

    print(f"Found {len(filtered_matrices)} matrices matching the criteria")
    # for matrix in filtered_matrices:
    #     print(f"  Name: {matrix['name']}, Rows: {matrix['rows']}, Cols: {matrix['cols']}, Sparsity: {matrix['sparsity']:.6f}")
    
    # Download and save matrices
    download_and_save_matrices(filtered_matrices, dest_dir)
# Out:
# Found 503 matrices matching the criteria
# Downloading matrix: bcsstk17
# bcsstk17:   0%|          | 0/1915413 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 93
#      88 print(f"Found {len(filtered_matrices)} matrices matching the criteria")
#      89 # for matrix in filtered_matrices:
#      90 #     print(f"  Name: {matrix['name']}, Rows: {matrix['rows']}, Cols: {matrix['cols']}, Sparsity: {matrix['sparsity']:.6f}")
#      91
#      92 # Download and save matrices
# ---> 93 download_and_save_matrices(filtered_matrices, dest_dir)
#
# Cell In[7], line 52, in download_and_save_matrices(filtered_matrices, dest_dir)
#      50 try:
#      51     matrix = ssgetpy.search(name=matrix_name,limit=50)[0]  # Search for the matrix
# ---> 52     download_path, extract_path = matrix.download(format='MM', destpath=dest_dir, extract=True)  # Download matrix
#      54     # Find and move .mtx file
#      55     extracted_dir = os.path.join(dest_dir, matrix_name)
#
# File /opt/miniconda3/lib/python3.12/site-packages/ssgetpy/matrix.py:209, in Matrix.download(self, format, destpath, extract)
#     207         outfile.write(chunk)
#     208         pbar.update(4096)
# --> 209         time.sleep(0.1)
#     211 if extract and (format == "MM" or format == "RB"):
#     212     bundle.extract(localdest)
#
# KeyboardInterrupt:

# %%
import os
import shutil
import json
import ssgetpy

def filter_matrices(filename, row_range=None, col_range=None, sparsity_range=None):
    """
    Filter matrices based on the row, column, and sparsity range.
    
    Parameters:
        filename (str): Path to the metadata file.
        row_range (tuple): Min and max number of rows.
        col_range (tuple): Min and max number of columns.
        sparsity_range (tuple): Min and max sparsity.

    Returns:
        list: Filtered matrix metadata.
    """
    if not os.path.exists(filename):
        print(f"Metadata file {filename} not found. Maybe run the fetch_and_store_results() first!")
        return []

    with open(filename, "r") as f:
        matrix_metadata = json.load(f)

    filtered = []
    for matrix in matrix_metadata:
        if row_range and not (row_range[0] <= matrix["rows"] <= row_range[1]):
            continue
        if col_range and not (col_range[0] <= matrix["cols"] <= col_range[1]):
            continue
        if sparsity_range and not (sparsity_range[0] <= matrix["sparsity"] <= sparsity_range[1]):
            continue
        filtered.append(matrix)

    return filtered

def download_and_save_matrices(filtered_matrices, dest_dir):
    """
    Download filtered matrices and save their .mtx files directly to the destination directory, instead of under a sub-folder.
    
    Parameters:
        filtered_matrices (list): List of filtered matrix metadata.
        dest_dir (str): Path to the directory where the .mtx files should be saved.
    """
    os.makedirs(dest_dir, exist_ok=True)

    for matrix_meta in filtered_matrices:
        matrix_name = matrix_meta["name"]
        mtx_file_path = os.path.join(dest_dir, f"{matrix_name}.mtx")

        # Check if the .mtx file already exists
        if os.path.exists(mtx_file_path):
            print(f"Matrix '{matrix_name}' already exists at {mtx_file_path}. Skipping download.")
            continue

        print(f"Downloading matrix: {matrix_name}")
        try:
            matrix = ssgetpy.search(name=matrix_name, limit=10)[0]  # Search for the matrix
            download_path, extract_path = matrix.download(format='MM', destpath=dest_dir, extract=True)  # Download matrix

            # Find and move .mtx file
            extracted_dir = os.path.join(dest_dir, matrix_name)
            mtx_files = [f for f in os.listdir(extracted_dir) if f.endswith('.mtx')]

            if not mtx_files:
                print(f"No .mtx file found for matrix: {matrix_name}")
                continue

            mtx_file = mtx_files[0]
            shutil.move(os.path.join(extracted_dir, mtx_file), mtx_file_path)

            # Remove the now-empty extracted folder
            shutil.rmtree(extracted_dir)
            print(f"Matrix '{matrix_name}' saved as: {mtx_file_path}")
        except Exception as e:
            print(f"Error downloading matrix '{matrix_name}': {e}")

if __name__ == "__main__":
    # Define filtering criteria
    row_range = (10000, 50000)         
    col_range = (10000, 50000)         
    sparsity_range = (0.9, 1.0) 

    metadata_file = "../ssmatrices/ss_matrix_metadata.json"
    dest_dir = "../ssmatrices"

    # Filter matrices
    filtered_matrices = filter_matrices(
        filename=metadata_file,
        row_range=row_range,
        col_range=col_range,
        sparsity_range=sparsity_range
    )

    print(f"Found {len(filtered_matrices)} matrices matching the criteria")
    
    # Download and save matrices
    download_and_save_matrices(filtered_matrices, dest_dir)
# Out:
# Found 503 matrices matching the criteria
# Downloading matrix: bcsstk17
# bcsstk17:   0%|          | 0/1915413 [00:00<?, ?B/s]
# Matrix 'bcsstk17' saved as: ../ssmatrices/bcsstk17.mtx
# Downloading matrix: bcsstk18
# bcsstk18:   0%|          | 0/709409 [00:00<?, ?B/s]
# Matrix 'bcsstk18' saved as: ../ssmatrices/bcsstk18.mtx
# Downloading matrix: bcsstk25
# bcsstk25:   0%|          | 0/1147553 [00:00<?, ?B/s]
# Matrix 'bcsstk25' saved as: ../ssmatrices/bcsstk25.mtx
# Downloading matrix: bcsstk29
# bcsstk29:   0%|          | 0/642731 [00:00<?, ?B/s]
# Matrix 'bcsstk29' saved as: ../ssmatrices/bcsstk29.mtx
# Downloading matrix: bcsstk30
# bcsstk30:   0%|          | 0/2330997 [00:00<?, ?B/s]
# Matrix 'bcsstk30' saved as: ../ssmatrices/bcsstk30.mtx
# Downloading matrix: bcsstk31
# bcsstk31:   0%|          | 0/1310801 [00:00<?, ?B/s]
# Matrix 'bcsstk31' saved as: ../ssmatrices/bcsstk31.mtx
# Downloading matrix: bcsstk32
# bcsstk32:   0%|          | 0/2187664 [00:00<?, ?B/s]
# Matrix 'bcsstk32' saved as: ../ssmatrices/bcsstk32.mtx
# Downloading matrix: bcsstm25
# bcsstm25:   0%|          | 0/119670 [00:00<?, ?B/s]
# Matrix 'bcsstm25' saved as: ../ssmatrices/bcsstm25.mtx
# Downloading matrix: onetone1
# onetone1:   0%|          | 0/1997386 [00:00<?, ?B/s]
# Matrix 'onetone1' saved as: ../ssmatrices/onetone1.mtx
# Downloading matrix: onetone2
# onetone2:   0%|          | 0/1303923 [00:00<?, ?B/s]
# Matrix 'onetone2' saved as: ../ssmatrices/onetone2.mtx
# Downloading matrix: epb1
# epb1:   0%|          | 0/956972 [00:00<?, ?B/s]
# Matrix 'epb1' saved as: ../ssmatrices/epb1.mtx
# Downloading matrix: epb2
# epb2:   0%|          | 0/1604248 [00:00<?, ?B/s]
# Matrix 'epb2' saved as: ../ssmatrices/epb2.mtx
# Downloading matrix: af23560
# af23560:   0%|          | 0/3504689 [00:00<?, ?B/s]
# Matrix 'af23560' saved as: ../ssmatrices/af23560.mtx
# Downloading matrix: bcsstk35
# bcsstk35:   0%|          | 0/6959360 [00:00<?, ?B/s]
# Matrix 'bcsstk35' saved as: ../ssmatrices/bcsstk35.mtx
# Downloading matrix: bcsstk36
# bcsstk36:   0%|          | 0/5435971 [00:00<?, ?B/s]
# Matrix 'bcsstk36' saved as: ../ssmatrices/bcsstk36.mtx
# Downloading matrix: bcsstk37
# bcsstk37:   0%|          | 0/5348044 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 99
#      96 print(f"Found {len(filtered_matrices)} matrices matching the criteria")
#      98 # Download and save matrices
# ---> 99 download_and_save_matrices(filtered_matrices, dest_dir)
#
# Cell In[8], line 60, in download_and_save_matrices(filtered_matrices, dest_dir)
#      58 try:
#      59     matrix = ssgetpy.search(name=matrix_name, limit=10)[0]  # Search for the matrix
# ---> 60     download_path, extract_path = matrix.download(format='MM', destpath=dest_dir, extract=True)  # Download matrix
#      62     # Find and move .mtx file
#      63     extracted_dir = os.path.join(dest_dir, matrix_name)
#
# File /opt/miniconda3/lib/python3.12/site-packages/ssgetpy/matrix.py:209, in Matrix.download(self, format, destpath, extract)
#     207         outfile.write(chunk)
#     208         pbar.update(4096)
# --> 209         time.sleep(0.1)
#     211 if extract and (format == "MM" or format == "RB"):
#     212     bundle.extract(localdest)
#
# KeyboardInterrupt:

# %%
'''
Downloads only max_matrices number of matrices after filtering
'''


import os
import shutil
import json
import ssgetpy

def filter_matrices(filename, row_range=None, col_range=None, sparsity_range=None):
    """
    Filter matrices based on the row, column, and sparsity range.
    
    Parameters:
        filename (str): Path to the metadata file.
        row_range (tuple): Min and max number of rows.
        col_range (tuple): Min and max number of columns.
        sparsity_range (tuple): Min and max sparsity.

    Returns:
        list: Filtered matrix metadata.
    """
    if not os.path.exists(filename):
        print(f"Metadata file {filename} not found. Maybe run the fetch_and_store_results() first!")
        return []

    with open(filename, "r") as f:
        matrix_metadata = json.load(f)

    filtered = []
    for matrix in matrix_metadata:
        if row_range and not (row_range[0] <= matrix["rows"] <= row_range[1]):
            continue
        if col_range and not (col_range[0] <= matrix["cols"] <= col_range[1]):
            continue
        if sparsity_range and not (sparsity_range[0] <= matrix["sparsity"] <= sparsity_range[1]):
            continue
        filtered.append(matrix)

    return filtered

def download_and_save_matrices(filtered_matrices, dest_dir, max_matrices=10):
    """
    Download filtered matrices and save their .mtx files directly to the destination directory, instead of under a sub-folder.
    
    Parameters:
        filtered_matrices (list): List of filtered matrix metadata.
        dest_dir (str): Path to the directory where the .mtx files should be saved.
        max_matrices (int): Maximum number of matrices to process.
    """
    os.makedirs(dest_dir, exist_ok=True)

    processed_count = 0
    for matrix_meta in filtered_matrices:
        if processed_count >= max_matrices:
            break

        matrix_name = matrix_meta["name"]
        mtx_file_path = os.path.join(dest_dir, f"{matrix_name}.mtx")

        # Check if the .mtx file already exists
        if os.path.exists(mtx_file_path):
            print(f"Matrix '{matrix_name}' already exists at {mtx_file_path}. Skipping download.")
            continue

        print(f"Downloading matrix: {matrix_name}")
        try:
            matrix = ssgetpy.search(name=matrix_name, limit=10)[0]  # Search for the matrix
            download_path, extract_path = matrix.download(format='MM', destpath=dest_dir, extract=True)  # Download matrix

            # Find and move .mtx file
            extracted_dir = os.path.join(dest_dir, matrix_name)
            mtx_files = [f for f in os.listdir(extracted_dir) if f.endswith('.mtx')]

            if not mtx_files:
                print(f"No .mtx file found for matrix: {matrix_name}")
                continue

            mtx_file = mtx_files[0]
            shutil.move(os.path.join(extracted_dir, mtx_file), mtx_file_path)

            # Remove the now-empty extracted folder
            shutil.rmtree(extracted_dir)
            print(f"Matrix '{matrix_name}' saved as: {mtx_file_path}")
            processed_count += 1
        except Exception as e:
            print(f"Error downloading matrix '{matrix_name}': {e}")

if __name__ == "__main__":
    # Define filtering criteria
    row_range = (10000, 50000)         
    col_range = (10000, 50000)         
    sparsity_range = (0.9, 1.0) 

    metadata_file = "../ssmatrices/ss_matrix_metadata.json"
    dest_dir = "../ssmatrices"

    # Filter matrices
    filtered_matrices = filter_matrices(
        filename=metadata_file,
        row_range=row_range,
        col_range=col_range,
        sparsity_range=sparsity_range
    )

    print(f"Found {len(filtered_matrices)} matrices matching the criteria")
    
    # Download and save up to 10 matrices
    download_and_save_matrices(filtered_matrices, dest_dir, max_matrices=10)
